# %% [markdown]
# # Final Project: Your Choice
#
# You have made it to the final week of the semester!

# %% [markdown]
# ### Logistics
#
# **Rules**: You are required to choose your own topic and complete your own work, with the help of the instructor if necessary. If you are using outside sources such as example code generated by AI, etc. please cite the source or the prompt that you used to generate the code.
#
# **Programming Environment**: You may choose to complete your work on the same notebook server as used for assignments and labs. You can add your work to this notebook and submit the completed the ```.ipynb``` and ```.html``` files in Canvas as you did for the assignments. If you need to use additional libraries that are not available through ```import```, you can use the shell command to install them. For excample, if you would like to use the ```pytorch``` library for training neural nets, you can do:
#
# ```!pip3 install torch```
#
# Alternatively, you can complete all programming on your own device. Simply download this notebook and run it on your device.
#
# **Support**: You are not alone! Come to office hours. If you're ever feeling overwhelmed or don't know how to make progress, email for help.
#
# ### Coverage
# The final project requires you to explore and analyze your own data set by leveraging the resources and ideas you learned during this semester. You can elect to collect the data yourself, use something from the class repository, or from other third-party sources. If you use online sources, you must cite the source of your data, and your statistical analysis must be original. Your project should cover each of the following areas:
#
# **Descriptive statistics**: graphic and numeric summaries of your data
#
# **Statistical Inference**: show examples of statistical inference by apply the techniques from this class. For example, based on the student data, we may ask:
# Is there a difference in average between students who do and do not use social media? (A/B testing)
# What is a 95% confidence interval for the difference between the average height of male and female students? (confidence interval by bootstrapping)
# Is there evidence to show there is a correlation between the Shoe size and Height of the male students? Can you predict the shoe size for a student who is 76 inches tall? (correlation and regression)
#
# **Classification**: show how you can predict the outcome of one of the variables by using a set of features by using a classifer (such as kNN, or other models available through ```sklearn```. Evaluate the performance of your classifier and discuss areas of further refinement.
# You should ask and address at least two areas mentioned above.

# %%
# Run this cell to set up the notebook, but please don't change it.
import numpy as np
import math, scipy, sklearn
import datascience

from datascience import *

# These lines set up the plotting functionality and formatting.
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ### Introduction (The Dataset)
#
# Describe your data below, including the necesary background and the meaning of the variables. If you have downloaded the data from the web, please identify its source.
