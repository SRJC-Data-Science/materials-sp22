# %% [markdown]
# # Day 1 Assignment - Using Jupyter Notebook #
#
# **Helpful Resource:**
# - [Python Reference](http://data8.org/sp22/python-reference.html)
# - [Jupyter Basics - Tips & Tricks](https://medium.com/@snehalgawas/back-to-basics-jupyter-notebooks-dfcdc19c54bc)

# %% [markdown]
# ## Cell ##
#
# In a Jupyter notebook, each of this box is called cell. A cell can be used for coding or text-editing. Like this one you are reading, is used for text-editing.
#
# Each cell also has two mode: edit and command modes.
#
# ## Follow the Instructions Below to Practice and Complete the Assignment ##
#
# You may not understand or even be confused. Don't worry! This assignment is for you to practice and get used to using Jupyter notebooks.

# %% [markdown]
# ### Part 1 ###

# %% [markdown]
# 1. Read [Jupyter Basics - Tips & Tricks](https://medium.com/@snehalgawas/back-to-basics-jupyter-notebooks-dfcdc19c54bc)
# 2. Select/Click this cell (if it is not yet selected)
# 3. Enter to edit mode (if not editable, hit Enter or double click the cell)
# 4. [Type your name and today's date here]
# 6. Run the cell
#
# ##### If you are not sure how to do it, feel free to refer to [Jupyter Basics - Tips & Tricks](https://medium.com/@snehalgawas/back-to-basics-jupyter-notebooks-dfcdc19c54bc) #####

# %% [markdown]
# ### Part 2 ###
#
# 1. Select/Click the cell below (NOT this cell, the following one)
# 2. Select "Code" from the dropdown menu above (if you see "Markdown" or "Raw", change it to "Code")
# 3. Type ```3 + 9``` in the cell
# 4. Run the cell
# 5. Then, you should see the answer

# %%
# Type 3 + 9 in the next line

# %% [markdown]
# ### Part 3 ###
#
# 1. Run the cell below
#
# Nothing will happen. It reads a CSV file and put it in a table (data frame) format

# %%
from datascience import *
djia = Table.read_table("djia.csv")

# %% [markdown]
# 2. In the cell below, type ```djia```
#
# It displays a table with ```Price```, ```Close```, ```High```, ```Low```, ```Open``` and ```Volume``` columns.

# %%
# Type djia in the next line

# %% [markdown]
# 3. In the cell below, type ```djia.relabeled("Price", "Date")```
#
# It changes the ```Price``` column name to ```Date```.

# %%
# Type djia.relabeled("Price", "Date") in the next line

# %% [markdown]
# ### Part 4 - Improvising Playground (Optional) ###
#
# Based on what you have learned from this assignment, play around with cells below.
#
# Create new cells, make them a markdown or code cell, toggle the cells between markdown and code... etc.
#
# Okay to make mistakes, create errors, try to fix it, fail to fix it... whatever!
#
# **Play, have fun and get familiar with Jupyter notebooks!**

# %% [markdown]
# ### Part 5 - Assignment Submission ###
#
# #### Instructions ####
#
# Follow the instructions below to complete this assignment:
#
# 1. Complete this notebook titled "Day 1 Assignment - Using Jupyter Notebook" .
# 2. In the Jupyter Notebook window, go to File, then Download. This will download the .ipynb file from the cloud to your desktop.
# 3. In the same Notebook window, go to File, select "Save and Export Notebook As", then select "HTML". This will export your notebook to an HTML file on your desktop.
# 4. Submit both files to this assignment in Canvas.
#
# If you encounter any issues, please check with the instructor.
#
# ### Future Assignment Submissions ###
#
# **You should follow the same process to submit all future assignments that involve Jupyter Notebooks.**
