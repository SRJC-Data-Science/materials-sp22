# %% [markdown]
# ### CS 8 Test 1: Live Coding Questions
#
# In this part of the test, you will have up to 1 hour to complete several problems that require coding and simulations. Please answer all questions within the notebook, and submit the code if needed. You are allowed to consult the course material in Canvas or handwritten notes, but please complete the test yourself within the time limit. Your completed notebook and HTML file must be submitted in Canvas before the stated time limit.

# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
cars = Table().read_table('Cars2025.csv')

# %% [markdown]
# ### Question 1:
#
# Among all the SUVs that weigh more than 4000 lbs, find the top 10 SUVs that have the shortest braking distance (```brake```). Show the first 10 rows of a table that contains make, model, braking distance and weight.

# %%
# your table should contain make, model, braking and weight
short_braking_SUV = ...

# show the 10 SUVs with the shortest braking distance from your table

# %% [markdown]
# ### Question 2
#
# Use the following bins to create a histogram for the WheelBase for the vehicles. Then use your histogram to estimate the percentage of vehicles that are longer than 130 inches?

# %%
equal_bins = np.arange(90, 160, 5)
# Create a histogram by using the bins specified above

# %%
# then use the histogram to estimate the percentage. Your answer does not need to be exact, 
# but must contain a formula that references the height in the histogram above
# you can estimate the height visually from the histogram

percent_more_than_130 = ...

# %% [markdown]
# ### Question 3
#
# Define a function that computes the footprint of the vehicle ($footprint = width\times length$), and use it to add a new column named ```Footprint``` to the ```cars``` table.

# %%
def footprint(...):
    ...
    return ...

# apply your function to the cars table here

# %% [markdown]
# ### Question 4
#
# Use ```group``` to create a table that shows the average CityMPG and HwyMPG of different types of vehicles (sedan, SUV, etc.)

# %%
# insert your code and output here

# %% [markdown]
# ### Question 5 (extra credit)
#
# The webiste ```caredge.com``` provides estimated 10-year maintenance cost for some of the vehicles listed in the ```cars``` table. Write your own code to find which vehicles will be cheapest to own by the following criteria:
#
# $TotalCost = LowPrice + MaintCost$

# %%
# here is the maintenace cost data 
cost = Table().read_table('maint_cost.csv')
