# %% [markdown]
# ### Test 1 Part 2 Sample Questions
#
# In this part of the test, you will have up to 1 hour to complete several problems that require coding and simulations. Please answer all questions within the notebook, and submit the code if needed. You are allowed to consult the course material in Canvas, but please complete the test yourself within the time limit. Your completed notebook and HTML file must be submitted in Canvas before the stated time limit.

# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
cars = Table().read_table('Cars2025.csv')

# %% [markdown]
# ### Question 1:
#
# Find the average low selling price of all pickup trucks in the 2015 data set.

# %%
avg_low_price = ...

# %% [markdown]
# ### Question 2:
#
# Use the definition of $Range = HwyMPG \times FuelCap$, add a new column ``Range" to the ```cars``` table, and use it to sort the table to show the top 10 cars of with the longest range in 2025. For example, Acura Integra should have a range of $42\cdot 12.4 = 520.8$ miles.

# %%
# Display make, model and range of the top 10 vehicles with the longest range

# %% [markdown]
# ### Question 3
#
# Use the following bins to create a histogram for the HwyMPG for the vehicles. Then use your histogram to estimate the percentage of vehicles that are getting less than 30MPG.

# %%
equal_bins = np.arange(15, 60, 5)
# Create a histogram by using the bins specified above

# %%
# Estimate the percentage of vehicles that are getting less than 30MPG by typing in an expression

percent_less_than_30mpg = ...

# %% [markdown]
# ### Question 4
#
# Define a function that converts pounds to kilos (note: 1 pound is aproximately 0.45 kilograms), and apply it to the ```Weight``` column of ```cars``` table.

# %%
def pounds2kilos(pounds):
    ...
    return ...

# apply your function to the cars table here

# %% [markdown]
# ### Question 5
#
# Use ```pivot``` to create a grid that shows the number of vehicles for each combination of Size and Type in the ```cars``` data.
#
# Example output:
#
#          Small   Medium  Large
# Sedan
# SUV
#
# ...

# %%
# insert your code and output here

# %% [markdown]
# ### Question 6:
#
# Use ```join``` to find the car models that were produced in both 2015 and 2025. Create a visualization that will help us determine whether there is an association between the low selling price of the same model in 2015 v.s. in 2025.

# %%
old_cars = Table().read_table('Cars2015_v1.csv')
# show your code using join
